# %% [markdown]
# # Example of DOPER - EV Fleet

# %% [markdown]
# ### This examples demonstrates the DOPER framework for a three EV fleet with about 150 kW building base load and 100 kW Photovoltaic (PV) generation.

# %%
import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
from pprint import pprint
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# from IPython.display import HTML
# HTML('''<script>
# code_show=true; 
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# } 
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()">
# <input type="submit" value="Click here to toggle on/off the raw code."></form>
# ''')

# %% [markdown]
# ### Import DOPER modules

# %% [markdown]
# DOPER consists of several modules which are imported here.

# %%
from doper import DOPER, get_solver, get_root, standard_report
from doper.models.basemodel import base_model
from doper.models.battery import add_battery
from doper.examples.example import parameter_add_evfleet, ts_inputs, test_default_parameter, ts_inputs_ev_schedule
from doper.plotting import plot_dynamic
# Out:
# WARNING:root:The default "cbc" solver was not properly installed at "D:\UNIVALLE\DESARROLLO\Ob2\Simulations\DOPER\doper\solvers\Linux64\cbc". Need to manually set the "solver_path" and "solver_name" when calling DOPER.

# %% [markdown]
# ### Setup Optimization Model

# %% [markdown]
# DOPER passes the inputs as first arguments and parameter as second argument to the optimization model (control_model). In this example two models are loaded:
# * the "base_model" with energy balance of on-site generation, e.g. Photovoltaic, and demand, e.g. building base laod
# * the "add_battery" model which adds individual batteries or electric vehicles, as defined by the input parameters
#
# An objective function is defined as the sum of energy and demand cost, eventual revenue from exporting energy, and from frequency regulation. The weighting between the objectives is again defined within the parameters of the model.

# %%
from pyomo.environ import Objective, minimize

def control_model(inputs, parameter):
    model = base_model(inputs, parameter)
    model = add_battery(model, inputs, parameter)
    
    def objective_function(model):
        return model.sum_energy_cost * parameter['objective']['weight_energy'] \
               + model.sum_demand_cost * parameter['objective']['weight_demand'] \
               + model.sum_export_revenue * parameter['objective']['weight_export']
              
    model.objective = Objective(rule=objective_function, sense=minimize, doc='objective function')
    return model

# %% [markdown]
# ### Load Example Parameter

# %% [markdown]
# The "parameter" dictinoary object includes all parameters of the optimization model. The high-level categories are:
# * Battery: parameter of all batteries in the model. This includes number of batteries, initial and final State of Charge, power, capacity, etc.
# * Controller: selection of controller options such as model timestep, optimization horizon, etc.
# * Objective: weighting of the multiple objectives
# * Site: specifications of the site such as timezone, import and export power limits, customer type, etc.
# * Tariff: electricity tariff specified as time-of-use with any number of periods

# %%
parameter = test_default_parameter()
parameter = parameter_add_evfleet(parameter)

print("parameter 'system' object:")
pprint(parameter['system'])
print('')

print("parameter 'batteries' object:")
pprint(parameter['batteries'])
print('')
# Out:
# parameter 'system' object:
# {'battery': True,
#  'external_gen': False,
#  'genset': False,
#  'hvac_control': False,
#  'load_control': False,
#  'pv': True,
#  'reg_bidding': False,
#  'reg_response': False}
#
# parameter 'batteries' object:
# [{'capacity': 24,
#   'efficiency_charging': 0.96,
#   'efficiency_discharging': 0.96,
#   'maxS': 15,
#   'name': 'EV0',
#   'power_charge': 15,
#   'power_discharge': 15,
#   'self_discharging': 0.003,
#   'soc_initial': 0.75,
#   'soc_max': 0.8,
#   'soc_min': 0.2},
#  {'capacity': 24,
#   'efficiency_charging': 0.96,
#   'efficiency_discharging': 0.96,
#   'maxS': 15,
#   'name': 'EV1',
#   'power_charge': 15,
#   'power_discharge': 15,
#   'self_discharging': 0.003,
#   'soc_initial': 0.8,
#   'soc_max': 0.8,
#   'soc_min': 0.2},
#  {'capacity': 54,
#   'efficiency_charging': 0.96,
#   'efficiency_discharging': 0.96,
#   'maxS': 30,
#   'name': 'EV2',
#   'power_charge': 30,
#   'power_discharge': 30,
#   'self_discharging': 0.003,
#   'soc_initial': 0.75,
#   'soc_max': 0.8,
#   'soc_min': 0.2}]

# %% [markdown]
# ### Load Example Data

# %% [markdown]
# The input data in this example is chosen to represent a medium-sized office building with rooftop photovoltaic system and three electric vehicles.

# %%
data = ts_inputs(parameter, load='B90', scale_load=150, scale_pv=100)
data = ts_inputs_ev_schedule(parameter, data)
# Out:
# D:\UNIVALLE\DESARROLLO\Ob2\Simulations\DOPER\doper\examples\example.py:1349: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.0, 0.3090169943749474, 0.5877852522924731, 0.8090169943749475, 0.9510565162951535, 1.0, 0.9510565162951536, 0.8090169943749475, 0.5877852522924732, 0.3090169943749475, 1.2246467991473532e-16]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[data.index[8:19], 'generation_pv'] = [np.sin(i/(10/(np.pi))) for i in range(11)]

# %% [markdown]
# ### Conduct Optimization

# %% [markdown]
# In order to conduct the optimization, the DOPER object is initialized with the model, parameter, and the pyomo_to_pandas converter function. In the next step, the model is evaluated with the "do_optimization" class function. It takes the current inputs as input and returns a list of results.
#
# Note that DOPER is built for application as Model Predictive Control (MPC) where the optimization model is periodically, e.g. every five minutes, updated with the most recent inputs, and reevaluated. However, in this example, do_optimization is only executed once.

# %%
# Define the path to the solver executable
solver_path = 'D:\\UNIVALLE\\DESARROLLO\\Ob2\\Simulations\\DOPER\\doper\\solvers\\Windows64\\cbc.exe'
print(solver_path)
# Initialize DOPER
smartDER = DOPER(model=control_model,
                 parameter=parameter,
                 solver_path=solver_path)

# Conduct optimization
res = smartDER.do_optimization(data)

# Get results
duration, objective, df, model, result, termination, parameter = res
print(standard_report(res))
# Out:
# D:\UNIVALLE\DESARROLLO\Ob2\Simulations\DOPER\doper\solvers\Windows64\cbc.exe
# Duration [s]		1.58
# Objective [$]		5483.31			5483.31 (Total Cost)
# Cost [$]		214.61 (Energy)	5268.7 (Demand)	0.0 (Revenue)
# CO2 Emissions [kg]		385.91

# %% [markdown]
# ### Result for Site

# %%
plotData = plot_dynamic(df, parameter, plotFile = None, plot_reg=False)

# %%
for comp in model.component_objects():
    print(comp)

print('Regulation revenue values = ', model.sum_regulation_revenue.value)
# Out:
# ts
# periods
# nodes
# tariff_energy
# tariff_power
# tariff_energy_export
# demand_periods_preset
# pv_max_s
# tariff_energy_map
# tariff_power_map
# tariff_energy_export_map
# tariff_regulation_up
# tariff_regulation_dn
# outside_temperature
# grid_available
# fuel_available
# grid_co2_intensity
# utility_rtp
# utility_rtp_export
# load_input
# generation_pv
# powerExchangeOut
# powerExchangeIn
# powerExchangeLosses
# external_gen_power
# load_served
# load_served_site
# generation_pv_site
# actual_generation_pv
# generation_pv_curtailed
# grid_import_site
# grid_export_site
# grid_import
# grid_export
# demand_charge_periods
# demand_charge_overall
# power_provided
# power_consumed
# grid_importXORexport
# co2_elec_import
# co2_elec_export
# co2_fuels
# co2_total
# co2_profile_elec_import
# co2_profile_elec_export
# co2_profile_fuels
# co2_profile_total
# energy_cost
# rtp_cost
# energy_export_revenue
# rtp_export_revenue
# sum_energy_cost
# sum_demand_cost
# sum_rtp_cost
# sum_export_revenue
# sum_rtp_export_revenue
# sum_regulation_revenue
# total_cost
# sum_battery_charge_grid_power
# sum_battery_discharge_grid_power
# sum_battery_charge_grid_power_site
# sum_battery_discharge_grid_power_site
# sum_genset_power
# sum_genset_power_site
# fuel_cost_total
# sum_genset_co2
# co2_profile_genset
# load_shed
# load_shed_cost_total
# load_shed_site
# load_shed_der_total
# building_load_dynamic
# constraint_outage_import
# constraint_outage_export
# constraint_power_provision
# constraint_power_consumption
# constraint_pv_actual_power
# constraint_pv_curtail_power
# constraint_energy_balance
# constraint_net_load_served_summation
# constraint_site_grid_imports
# constraint_site_grid_exports
# constraint_site_load_served_agg
# constraint_site_pv_gen_agg
# constraint_demand_maximum
# constraint_demand_overall
# constraint_limit_physical_import
# constraint_grid_import_XOR_export
# constraint_grid_export_XOR_import
# constraint_grid_import_emissions
# constraint_grid_export_emissions
# constraint_grid_import_emissions_profile
# constraint_grid_export_emissions_profile
# constraint_fuel_use_emissions
# constraint_total_co2_emission
# constraint_co2_emissions_profile
# constraint_energy_cost_calculation
# constraint_energy_export_revenue_calculation
# constraint_sum_energy_cost
# constraint_sum_export_revenue
# constraint_rtp_cost_calculation
# constraint_rtp_export_revenue_calculation
# constraint_sum_rtp_cost
# constraint_sum_rtp_export_revenue
# constraint_sum_demand_cost
# constraint_total_cost
# batteries
# battery_available
# battery_demand_ext
# bat_capacity
# bat_eff_charge
# bat_eff_discharge
# bat_power_charge
# bat_power_discharge
# bat_self_discharge
# bat_soc_end
# bat_soc_init
# bat_soc_min
# bat_soc_max
# bat_max_s
# battery_node_location
# sum_battery_selfdischarge_power
# battery_charge_power
# battery_discharge_power
# battery_chargeXORdischarge
# battery_soc
# battery_agg_soc
# battery_charge_grid_power
# battery_discharge_grid_power
# battery_energy
# battery_selfdischarge_power
# constraint_battery_soc
# constraint_battery_soc_aggregation
# constraint_battery_charge_losses
# constraint_battery_discharge_losses
# constraint_battery_selfdischarge_losses
# constraint_battery_energy_balance
# constraint_battery_charge_XOR_discharge
# constraint_battery_discharge_XOR_charge
# constraint_sum_battery_charge_grid
# constraint_sum_battery_discharge_grid
# constraint_site_total_battery_charge
# constraint_site_total_battery_discharge
# objective
# Regulation revenue values =  None
